# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
def read_and_analyze_data(file_path):
    # Read the data from the CSV file
    data = pandas.read_csv(file_path)
    data= data.drop(columns=['id'], axis=1)
    # Perform some basic analysis
    print("Data Summary:")
    #print(data.describe())
    print(data.isnull().sum())
    # Plotting the data
    #data.plot()
    
read_and_analyze_data('/home/navneet/Kaggle_comp/playground-series-s5e5/train.csv')
# Out:
# Data Summary:
# Sex           0
# Age           0
# Height        0
# Weight        0
# Duration      0
# Heart_Rate    0
# Body_Temp     0
# Calories      0
# dtype: int64

# %%
read_data = pd.read_csv('/home/navneet/Kaggle_comp/playground-series-s5e5/train.csv')   
read_data = read_data.drop(columns=['id'], axis=1)
read_data = read_data.dropna()
read_data = read_data.drop_duplicates()
read_data = read_data.reset_index(drop=True)
read_data = read_data.drop(columns=['Calories'], axis=1)
total_columns = read_data.columns
print("Total columns in the dataset:", len(total_columns))
fig,axa = plt.subplots(3, 4, figsize=(15, 5))
for i in range(3):
    for j in range(4):
        if i*4+j < len(total_columns):
            sns.histplot(data=read_data, x=total_columns[i*4+j], ax=axa[i][j])
            axa[i][j].set_title(total_columns[i*4+j])
        else:
            axa[i][j].axis('off')
plt.tight_layout()
plt.show()
fig, axb = plt.subplots(1, len(total_columns), figsize=(20, 5))
for idx, column in enumerate(total_columns):
    sns.boxplot(data=read_data, y=column, ax=axb[idx])
    axb[idx].set_title(column)
plt.tight_layout()
plt.show()
# Out:
# Total columns in the dataset: 7
